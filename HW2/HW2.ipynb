# %% [markdown]
# <a href="https://colab.research.google.com/github/asir928/IDS/blob/main/HW2/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Asir Nayeef
#
# # Project 2
#
#
# # Problem 1:
#
# Assault rates was converted to be on par with murder rates. Formula was used to categorize the urban populate percentages.
#
# Excel charts:
#
# Murder rates of all states:
#
# ![Screenshot 2023-09-26 130121.png](data:image/png;base64,...)
#
# Histogram of assaults:
#
# ![Screenshot 2023-09-26 130135.png](data:image/png;base64,...)
#
# Murder vs assault rates:
# ![Screenshot 2023-09-26 130211.png](data:image/png;base64,...)
#
# Urban population categorized in Excel file USArrests.xlsx
#
# There seems to be more instances of assault as urban population goes up.
#
# SQL Script: Problem 1.sql
#
# Arizona has the maximum murder rate
#
# 21 states have higher murder rates than Arizona.
#
# # Problem 2:
#
# Missing values were handled by adding and dividing the rates for the years between them by 2.
#
# Likert scales made by dividing the percentages by 20 and formattiing them to be whole 5-point numbers.
#
# Underfive mortality rates dropped more linearly than the neonatal mortality rate
#
# Neonatal rates dropped less linearly than the infant mortality rate
#
# The infant mortality rate would have a large drop at the starting year and it would drop less and less over the coming years.
#
# Dataset spreadsheet saved as child mortality.xlsx
#
# SQL Script: Problem 2.sql
#
# 2016 and 1990 had the highest and lowest infant mortality rates respectively
#
# Neonatal mortality rates were the highest during years 1990 to 2003
#
# JSON conversion saved as  Problem 2.json
# XML conversion saved as Problem 2.xml
