# %% [markdown]
# <a href="https://colab.research.google.com/github/asir928/IDS/blob/main/Project%201/Project%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Problem 1: Figuring out what feed will grow the healthiest chickens**
#
# Screenshot of chicken feeds, alongside the total, minimum, mean, and maximum amount for each calculated with Excel:
#
# ![Screenshot 2023-09-02 171209.png](data:image/png;base64,...)
#
# Screenshot of chart showing the total amounts by type of feed used:
# ![Screenshot 2023-09-02 174114.png](data:image/png;base64,...)
#
# From my analysis, i believe that the option for growing the healthiest chickens for KFC would be the sunflower feed. The sunflower feed has the highest mean value, maximum value, and minimum value.
#
# The table of values are included in a spreadsheet named Project1-Q1.xlsx with the chart and a CSV file named project1-Q1.csv without the chart.
#
# ###**Problem 2: Analyze the insurance values**
#
# Screenshot of the data table as well as minimum, maximum and mean values:
# ![Screenshot 2023-09-02 203611.png](data:image/png;base64,...)
#
# From the analysis, Progressive has the higher mean value, making it the insurance company I would opt for.
#
# The data tables are saved in this repository as both a CSV file, named Project1-Q2.csv, and an Excel workbook, named Project1-Q2.xlsx.
